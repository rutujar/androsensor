# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.__version__
# Out:
# '0.20.3'

# %%
# %matplotlib inline

# %%
import pandas as pd
sf = pd.read_csv('data.csv')
sf.head()
# Out:
#    ACCEX  ACCEY  ACCEZ    GRAVX    GRAVY    GRAVZ    LACCX    LACCY    LACCZ  \
# 0 -0.356  4.593  8.511 -0.18187  5.34846  8.21774 -0.17413 -0.75546  0.29326
# 1 -2.353  4.213  6.266  0.63113  5.37449  8.17844 -1.33113 -0.83449 -0.95244
# 2  2.528  4.762  8.047  1.96579  5.51084  7.86999  1.34321 -0.20584  0.62901
# 3  1.856  5.247  9.956  2.34833  5.01461  8.09379 -0.73251  0.03374  1.06761
# 4  0.707  4.520  8.404  1.95567  5.24552  8.05172 -1.13291 -0.62942  0.26345
#
#      GYROX           ...                 LOCAT     LOCAL  \
# 0  0.06875           ...             12.926521  77.68379
# 1  0.17253           ...             12.926521  77.68379
# 2 -0.03997           ...             12.926521  77.68379
# 3 -0.03637           ...             12.926521  77.68379
# 4 -0.21823           ...             12.926521  77.68379
#
#    LOCATION Altitude ( m)  LOCATION Altitude-google ( m)  \
# 0                     NaN                     2881.55003
# 1                     NaN                     2881.55003
# 2                     NaN                     2881.55003
# 3                     NaN                     2881.55003
# 4                     NaN                     2881.55003
#
#    LOCATION Speed ( Kmh)  LOCATION Accuracy ( m)  LOCATION ORIENTATION (°)  \
# 0                    NaN               2809.6775                       NaN
# 1                    NaN               2809.6775                       NaN
# 2                    NaN               2809.6775                       NaN
# 3                    NaN               2809.6775                       NaN
# 4                    NaN               2809.6775                       NaN
#
#    Satellites in range  Time since start in ms                      date
# 0               0 / 21                       10  2018-08-06 15:01:06:525
# 1               0 / 21                      511  2018-08-06 15:01:07:026
# 2               0 / 21                     1010  2018-08-06 15:01:07:525
# 3               0 / 21                     1510  2018-08-06 15:01:08:025
# 4               0 / 21                     2010  2018-08-06 15:01:08:525
#
# [5 rows x 31 columns]

# %%
sf.drop(sf.columns[[0, 2, 3, 15, 17, 18]], axis=1, inplace=True)
sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 25 columns):
# ACCEY                            203 non-null float64
# GRAVY                            203 non-null float64
# GRAVZ                            203 non-null float64
# LACCX                            203 non-null float64
# LACCY                            203 non-null float64
# LACCZ                            203 non-null float64
# GYROX                            203 non-null float64
# GYROY                            203 non-null float64
# GYROZ                            203 non-null float64
# LIGHT                            203 non-null int64
# MAFIX                            203 non-null float64
# MAFIY                            203 non-null float64
# ORIEZ                            203 non-null float64
# PROX                             203 non-null float64
# SOUND                            203 non-null float64
# LOCAT                            203 non-null float64
# LOCAL                            203 non-null float64
# LOCATION Altitude ( m)           0 non-null float64
# LOCATION Altitude-google ( m)    203 non-null float64
# LOCATION Speed ( Kmh)            0 non-null float64
# LOCATION Accuracy ( m)           203 non-null float64
# LOCATION ORIENTATION (°)         0 non-null float64
# Satellites in range              203 non-null object
# Time since start in ms           203 non-null int64
# date                             203 non-null object
# dtypes: float64(21), int64(2), object(2)
# memory usage: 39.7+ KB

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
sf.hist(bins=50, figsize=(20,15))
plt.savefig("attribute_histogram_plots")
plt.show()

# %%
sf.plot(kind="scatter", x="LOCAL", y="LOCAT", alpha=0.2)
plt.savefig('map1.png')

# %%
sf.plot(kind="scatter", x="LOCAL", y="LOCAT", alpha=0.4, figsize=(10,5),
    c="ACCEY", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)

# %%
from pandas.tools.plotting import scatter_matrix
attributes = ["LOCAL", "LIGHT", "PROX", "LACCX"]
scatter_matrix(sf[attributes], figsize=(12, 8))
plt.savefig('matrix.png')
# Out:
# /srv/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
